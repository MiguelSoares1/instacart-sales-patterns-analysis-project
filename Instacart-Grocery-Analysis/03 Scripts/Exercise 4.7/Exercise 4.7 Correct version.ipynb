# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\toloz\Instacart Basket Analysis 9_11_2024"

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'ords_prods_merge.pkl'))

# %%
df_orders_products_combined.shape
# Out:
# (32404859, 15)

# %%
df = df_orders_products_combined[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.loc['price_range'] = df_orders_products_combined.apply(price_label, axis=1)

# %%
df['prices'].max()

# %%
 df_orders_products_combined.loc[df_orders_products_combined['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
 df_orders_products_combined.loc[(df_orders_products_combined['prices'] <= 15) & (df_orders_products_combined['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
 df_orders_products_combined.loc[df_orders_products_combined['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_orders_products_combined['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
result = []

for value in df_orders_products_combined["order_dow"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_orders_products_combined['busiest day'] = result

# %%
 df_orders_products_combined['busiest day'].value_counts(dropna = False)
# Out:
# busiest day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
 df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices merge_indicator  \
# ...

# %% [markdown]
# # Directions

# %% [markdown]
# 1. If you haven’t done so already, complete the instructions in the Exercise for creating the “price_label” and “busiest_day” columns.

# %%
# As we can see here we have the price_label and busiest_day
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices merge_indicator  \
# ...

# %% [markdown]
# 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column.
# Now, they want “Busiest day” to become “Busiest days” (plural).
# This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# busiest days 
#results = []

#for value in df_orders_products_combined["order_dow"]:
   # if value == 0 :
      #  result.append("Busiest day")
   # elif value == 4:
      #  result.append("Least busy")
  #  else:
      #  result.append("Regularly busy")

df_orders_products_combined['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. 
# Now, they want “Busiest day” to become “Busiest days” (plural). 
#This label should correspond with the two busiest days of the week as opposed to the single busiest day. 
#At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# So I Think I just need to add an & to it to work
# also it says create a new column does that mean I should delete the last one or it says?
#busiest days

# %%
results = []
for value in df_orders_products_combined["order_dow"]:
    if (value == 0) | (value == 1) :
        results.append("Busiest days")
    elif (value == 4) | (value == 3):
        results.append("two slowest days")
    else:
        results.append("Regularly busy")

# %%
results
# Out:
# ['Regularly busy',
#  'two slowest days',
#  'two slowest days',
#  'two slowest days',
#  'two slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'two slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'two slowest days',
#  'two slowest days',
#  'two slowest days',
#  'two slowest days',
#  'two slowest days',
#  'two slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'two slowest days',
#  'Regularly busy',
#  'two slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'two slowest days',
#  'two slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
df_orders_products_combined['busiest days'] = results

# %% [markdown]
# # Step 3. Check values of new "busiest days" column for accuracy with observations in markdown format.

# %%
 df_orders_products_combined['busiest days'].value_counts(dropna = False)
# Out:
# busiest days
# Regularly busy      12916111
# Busiest days        11864412
# two slowest days     7624336
# Name: count, dtype: int64

# %%
 df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices merge_indicator  \
# ...

# %% [markdown]
# # 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
 df_orders_products_combined['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
results2 = []

for value in  df_orders_products_combined["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    results2.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    results2.append("Fewest orders")
  else:
    results2.append("Average orders")

# %%
 df_orders_products_combined['busiest_period_of_day'] = results2

# %% [markdown]
# # 5. Print the frequency for this new column.

# %%
df_orders_products_combined['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %%
# Export 
df_orders_products_combined.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))
